# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import seaborn as sb 
# 온라인 표시를 위해 그림 크기 조정
plt.rcParams['figure.figsize'] = (12.0, 10.0)

# %% [markdown]
# # 데이터셋 읽어오기

# %%
############################## read.csv ##################################
## 속성값
## : parse_dates[index or 'column'] : date형태의 칼럼을 넣는다
## : nrows = n : n개의 행만 read
## : dtype = 변수 : date type 지정

types = {'StateHoliday': np.dtype(str)}

train = pd.read_csv(r"./train.csv", parse_dates=[2], nrows=66901, dtype=types)
store = pd.read_csv(r"./store.csv")

# %%
train.head()

# %% [markdown]
# ## 데이터셋 확인

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
train.shape
# Out:
# (66901, 9)

# %%
store.shape
# Out:
# (1115, 10)

# %%
############################## 결측값 제거 ##################################

# train = train.dropna(axis=0)
# store = store.dropna(axis=0)

# %% [markdown]
# ## 데이터셋 2개를 Store를 기준으로 merge

# %%
df = pd.merge(train,store, on='Store', how='left') # default값 how='left'

# %%
df
# Out:
#        Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0          1          5 2015-07-31   5263        555     1      1
# 1          2          5 2015-07-31   6064        625     1      1
# 2          3          5 2015-07-31   8314        821     1      1
# 3          4          5 2015-07-31  13995       1498     1      1
# 4          5          5 2015-07-31   4822        559     1      1
# ...      ...        ...        ...    ...        ...   ...    ...
# 66896   1112          2 2015-06-02  12605        943     1      1
# 66897   1113          2 2015-06-02   7777        742     1      1
# 66898   1114          2 2015-06-02  25009       3419     1      1
# 66899   1115          2 2015-06-02   9232        558     1      1
# 66900      1          1 2015-06-01   5774        607     1      1
#
#       StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                0              1         c          a               1270.0
# 1                0              1         a          a                570.0
# 2                0              1         a          a              14130.0
# 3                0              1         c          c                620.0
# 4                0              1         a          a              29910.0
# ...            ...            ...       ...        ...                  ...
# 66896            0              0         c          c               1880.0
# 66897            0              0         a          c               9260.0
# 66898            0              0         a          c                870.0
# 66899            0              0         d          c               5350.0
# 66900            0              0         c          a               1270.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           11.0                    2007.0       1
# 2                           12.0                    2006.0       1
# 3                            9.0                    2009.0       0
# 4                            4.0                    2015.0       0
# ...                          ...                       ...     ...
# 66896                        4.0                    2006.0       0
# 66897                        NaN                       NaN       0
# 66898                        NaN                       NaN       0
# 66899                        NaN                       NaN       1
# 66900                        9.0                    2008.0       0
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                  NaN              NaN               NaN
# 1                 13.0           2010.0   Jan,Apr,Jul,Oct
# 2                 14.0           2011.0   Jan,Apr,Jul,Oct
# 3                  NaN              NaN               NaN
# 4                  NaN              NaN               NaN
# ...                ...              ...               ...
# 66896              NaN              NaN               NaN
# 66897              NaN              NaN               NaN
# 66898              NaN              NaN               NaN
# 66899             22.0           2012.0  Mar,Jun,Sept,Dec
# 66900              NaN              NaN               NaN
#
# [66901 rows x 18 columns]

# %% [markdown]
# # 결측값(=NaN) 0으로 변환

# %%
## NaN값 0으로 replace
df = df.fillna(0)

# %%
df
# Out:
#        Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0          1          5 2015-07-31   5263        555     1      1
# 1          2          5 2015-07-31   6064        625     1      1
# 2          3          5 2015-07-31   8314        821     1      1
# 3          4          5 2015-07-31  13995       1498     1      1
# 4          5          5 2015-07-31   4822        559     1      1
# ...      ...        ...        ...    ...        ...   ...    ...
# 66896   1112          2 2015-06-02  12605        943     1      1
# 66897   1113          2 2015-06-02   7777        742     1      1
# 66898   1114          2 2015-06-02  25009       3419     1      1
# 66899   1115          2 2015-06-02   9232        558     1      1
# 66900      1          1 2015-06-01   5774        607     1      1
#
#       StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                0              1         c          a               1270.0
# 1                0              1         a          a                570.0
# 2                0              1         a          a              14130.0
# 3                0              1         c          c                620.0
# 4                0              1         a          a              29910.0
# ...            ...            ...       ...        ...                  ...
# 66896            0              0         c          c               1880.0
# 66897            0              0         a          c               9260.0
# 66898            0              0         a          c                870.0
# 66899            0              0         d          c               5350.0
# 66900            0              0         c          a               1270.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           11.0                    2007.0       1
# 2                           12.0                    2006.0       1
# 3                            9.0                    2009.0       0
# 4                            4.0                    2015.0       0
# ...                          ...                       ...     ...
# 66896                        4.0                    2006.0       0
# 66897                        0.0                       0.0       0
# 66898                        0.0                       0.0       0
# 66899                        0.0                       0.0       1
# 66900                        9.0                    2008.0       0
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                  0.0              0.0                 0
# 1                 13.0           2010.0   Jan,Apr,Jul,Oct
# 2                 14.0           2011.0   Jan,Apr,Jul,Oct
# 3                  0.0              0.0                 0
# 4                  0.0              0.0                 0
# ...                ...              ...               ...
# 66896              0.0              0.0                 0
# 66897              0.0              0.0                 0
# 66898              0.0              0.0                 0
# 66899             22.0           2012.0  Mar,Jun,Sept,Dec
# 66900              0.0              0.0                 0
#
# [66901 rows x 18 columns]

# %% [markdown]
# # Date값 Year / Month / Day로 나누기

# %%
############# Datetime -> String 형변환 -> 구분자로 나누기 작업 #################
df['Year'] = df.Date.dt.year
df['Month'] = df.Date.dt.month
df['Day'] = df.Date.dt.day

# %%
#################### Date 삭제 ##########################

df.drop(labels='Date',axis=1, inplace=True)

# %%
df
# Out:
#        Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0          1          5   5263        555     1      1            0
# 1          2          5   6064        625     1      1            0
# 2          3          5   8314        821     1      1            0
# 3          4          5  13995       1498     1      1            0
# 4          5          5   4822        559     1      1            0
# ...      ...        ...    ...        ...   ...    ...          ...
# 66896   1112          2  12605        943     1      1            0
# 66897   1113          2   7777        742     1      1            0
# 66898   1114          2  25009       3419     1      1            0
# 66899   1115          2   9232        558     1      1            0
# 66900      1          1   5774        607     1      1            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  1         c          a               1270.0
# 1                  1         a          a                570.0
# 2                  1         a          a              14130.0
# 3                  1         c          c                620.0
# 4                  1         a          a              29910.0
# ...              ...       ...        ...                  ...
# 66896              0         c          c               1880.0
# 66897              0         a          c               9260.0
# 66898              0         a          c                870.0
# 66899              0         d          c               5350.0
# 66900              0         c          a               1270.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           11.0                    2007.0       1
# 2                           12.0                    2006.0       1
# 3                            9.0                    2009.0       0
# 4                            4.0                    2015.0       0
# ...                          ...                       ...     ...
# 66896                        4.0                    2006.0       0
# 66897                        0.0                       0.0       0
# 66898                        0.0                       0.0       0
# 66899                        0.0                       0.0       1
# 66900                        9.0                    2008.0       0
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval  Year  Month  Day
# 0                  0.0              0.0                 0  2015      7   31
# 1                 13.0           2010.0   Jan,Apr,Jul,Oct  2015      7   31
# 2                 14.0           2011.0   Jan,Apr,Jul,Oct  2015      7   31
# 3                  0.0              0.0                 0  2015      7   31
# 4                  0.0              0.0                 0  2015      7   31
# ...                ...              ...               ...   ...    ...  ...
# 66896              0.0              0.0                 0  2015      6    2
# 66897              0.0              0.0                 0  2015      6    2
# 66898              0.0              0.0                 0  2015      6    2
# 66899             22.0           2012.0  Mar,Jun,Sept,Dec  2015      6    2
# 66900              0.0              0.0                 0  2015      6    1
#
# [66901 rows x 20 columns]

# %% [markdown]
# # 인코딩 작업

# %%
############# 인코딩 작업을 위한 유닛값 찾아보기 ################

df['Promo2SinceYear'].unique()
# Out:
# array([   0., 2010., 2011., 2012., 2009., 2014., 2015., 2013.])

# %%
############################ 인코딩 함수 만들기 ############################

def label_encode(df, col):
    df_labelled_encode = df.copy()
    # 다른 클래스에 대해 다른 숫자를 지정하는 딕셔너리
    label_encode = {col: {'a':0, 'b':1, 'c':2, 'd':3}}
    # .replace를 사용하여 서로 다른 클래스를 숫자로 변경
    df_labelled_encode.replace(label_encode,inplace=True)
    return df_labelled_encode

# %%
############################ 인코딩 작업 ############################

df = label_encode(df, "Assortment")

# %%
############################ 인코딩 작업 ############################

df = label_encode(df, "StateHoliday")

# %%
############################ 인코딩 작업 ############################

df = label_encode(df, "StoreType")

# %%
df
# Out:
#        Store  DayOfWeek  Sales  Customers  Open  Promo  StateHoliday  \
# 0          1          5   5263        555     1      1             0
# 1          2          5   6064        625     1      1             0
# 2          3          5   8314        821     1      1             0
# 3          4          5  13995       1498     1      1             0
# 4          5          5   4822        559     1      1             0
# ...      ...        ...    ...        ...   ...    ...           ...
# 66896   1112          2  12605        943     1      1             0
# 66897   1113          2   7777        742     1      1             0
# 66898   1114          2  25009       3419     1      1             0
# 66899   1115          2   9232        558     1      1             0
# 66900      1          1   5774        607     1      1             0
#
#        SchoolHoliday  StoreType  Assortment  CompetitionDistance  \
# 0                  1          2           0               1270.0
# 1                  1          0           0                570.0
# 2                  1          0           0              14130.0
# 3                  1          2           2                620.0
# 4                  1          0           0              29910.0
# ...              ...        ...         ...                  ...
# 66896              0          2           2               1880.0
# 66897              0          0           2               9260.0
# 66898              0          0           2                870.0
# 66899              0          3           2               5350.0
# 66900              0          2           0               1270.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           11.0                    2007.0       1
# 2                           12.0                    2006.0       1
# 3                            9.0                    2009.0       0
# 4                            4.0                    2015.0       0
# ...                          ...                       ...     ...
# 66896                        4.0                    2006.0       0
# 66897                        0.0                       0.0       0
# 66898                        0.0                       0.0       0
# 66899                        0.0                       0.0       1
# 66900                        9.0                    2008.0       0
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval  Year  Month  Day
# 0                  0.0              0.0                 0  2015      7   31
# 1                 13.0           2010.0   Jan,Apr,Jul,Oct  2015      7   31
# 2                 14.0           2011.0   Jan,Apr,Jul,Oct  2015      7   31
# 3                  0.0              0.0                 0  2015      7   31
# 4                  0.0              0.0                 0  2015      7   31
# ...                ...              ...               ...   ...    ...  ...
# 66896              0.0              0.0                 0  2015      6    2
# 66897              0.0              0.0                 0  2015      6    2
# 66898              0.0              0.0                 0  2015      6    2
# 66899             22.0           2012.0  Mar,Jun,Sept,Dec  2015      6    2
# 66900              0.0              0.0                 0  2015      6    1
#
# [66901 rows x 20 columns]

# %% [markdown]
# ### 영향없는 PromoInterval 제거

# %%
############################ 영향없는 컬럼 drop ############################

df.drop(labels='PromoInterval',axis=1, inplace=True)
df
# Out:
#        Store  DayOfWeek  Sales  Customers  Open  Promo  StateHoliday  \
# 0          1          5   5263        555     1      1             0
# 1          2          5   6064        625     1      1             0
# 2          3          5   8314        821     1      1             0
# 3          4          5  13995       1498     1      1             0
# 4          5          5   4822        559     1      1             0
# ...      ...        ...    ...        ...   ...    ...           ...
# 66896   1112          2  12605        943     1      1             0
# 66897   1113          2   7777        742     1      1             0
# 66898   1114          2  25009       3419     1      1             0
# 66899   1115          2   9232        558     1      1             0
# 66900      1          1   5774        607     1      1             0
#
#        SchoolHoliday  StoreType  Assortment  CompetitionDistance  \
# 0                  1          2           0               1270.0
# 1                  1          0           0                570.0
# 2                  1          0           0              14130.0
# 3                  1          2           2                620.0
# 4                  1          0           0              29910.0
# ...              ...        ...         ...                  ...
# 66896              0          2           2               1880.0
# 66897              0          0           2               9260.0
# 66898              0          0           2                870.0
# 66899              0          3           2               5350.0
# 66900              0          2           0               1270.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           11.0                    2007.0       1
# 2                           12.0                    2006.0       1
# 3                            9.0                    2009.0       0
# 4                            4.0                    2015.0       0
# ...                          ...                       ...     ...
# 66896                        4.0                    2006.0       0
# 66897                        0.0                       0.0       0
# 66898                        0.0                       0.0       0
# 66899                        0.0                       0.0       1
# 66900                        9.0                    2008.0       0
#
#        Promo2SinceWeek  Promo2SinceYear  Year  Month  Day
# 0                  0.0              0.0  2015      7   31
# 1                 13.0           2010.0  2015      7   31
# 2                 14.0           2011.0  2015      7   31
# 3                  0.0              0.0  2015      7   31
# 4                  0.0              0.0  2015      7   31
# ...                ...              ...   ...    ...  ...
# 66896              0.0              0.0  2015      6    2
# 66897              0.0              0.0  2015      6    2
# 66898              0.0              0.0  2015      6    2
# 66899             22.0           2012.0  2015      6    2
# 66900              0.0              0.0  2015      6    1
#
# [66901 rows x 19 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Datetime -> String 형변환(사용X)

# %% [markdown]
# ###  나중에 df_test['Year'] = df_test['Date'].dt.year 사용해서 변경함

# %%
df_data = df['Date']
type(df_data[0])
# Out:
# numpy.int64

# %%
ts_str = []
for i in range(len(df_data)):
    ts_str.append(str(df_data[i]))

# %%
ts_str
# Out:
# ['2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  '2015-07-31 00:00:00',
#  ...]

# %%
#train01
X = []
date_data = []
time_data = []

for i in range(len(ts_str)):
    X = ts_str[i].split()
    #print(X)
    date_data.append(X[0])
    time_data.append(X[1])

# %%
##############time_data는 전부 다 00:00:00이므로 필요 없음##############

set(time_data)
# Out:
# {'00:00:00'}

# %%
import re

result = []
for i in range(len(date_data)):
    X = re.sub("-", "", date_data[i])
    result.append(X)

result
# Out:
# ['20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  '20150731',
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # target / featrues 지정

# %%
######################### target 값 지정 #############################
df_target_Sales = df['Sales']
df_target_Customers = df['Customers']

# %%
######################### feature 값 지정 #############################

df_features = df.copy() # copy

######################### target 값 삭제 #############################
df_features.drop(labels='Sales',axis=1, inplace=True)
df_features.drop(labels='Customers',axis=1, inplace=True)

# %%
df_features.head()
# Out:
#    Store  DayOfWeek  Open  Promo  StateHoliday  SchoolHoliday  StoreType  \
# 0      1          5     1      1             0              1          2
# 1      2          5     1      1             0              1          0
# 2      3          5     1      1             0              1          0
# 3      4          5     1      1             0              1          2
# 4      5          5     1      1             0              1          0
#
#    Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0           0               1270.0                        9.0
# 1           0                570.0                       11.0
# 2           0              14130.0                       12.0
# 3           2                620.0                        9.0
# 4           0              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  Year  \
# 0                    2008.0       0              0.0              0.0  2015
# 1                    2007.0       1             13.0           2010.0  2015
# 2                    2006.0       1             14.0           2011.0  2015
# 3                    2009.0       0              0.0              0.0  2015
# 4                    2015.0       0              0.0              0.0  2015
#
#    Month  Day
# 0      7   31
# 1      7   31
# 2      7   31
# 3      7   31
# 4      7   31

# %%
df_features.shape
# Out:
# (66901, 17)

# %% [markdown]
# # 데이터셋 나누기

# %%
############################ train / test data 나누기(Sales) ############################
# train_features
# train_target

from sklearn.model_selection import train_test_split
X_train_S, X_test_S, y_train_S, y_test_S = train_test_split(df_features, df_target_Sales, 
                                                    test_size=0.2, 
                                                    random_state=150, # 내부적으로 사용되는 난수 값
                                                    shuffle=True) #  데이터를 분리할 때 랜덤으로 분리할지의 유무
                                                     
# stratify (array) : 분리하기 이전의 클래스 비율을 분리하고 나서도 유지하기 위해 설정해야 하는 값 (종속변수의 컬럼을 넣어주면 됩니다.)
# 원본 데이터의 클래스 비율이 8:2라면 분리된 train data, valid(test) data의 클래스 비율도 8:2가 유지됩니다.
# 따라서 stratify 파라미터는 분류 문제에서만 사용 가능합니다.

# %%
############################ train / test data 나누기(Customers) ############################
# train_features
# train_target

from sklearn.model_selection import train_test_split
X_train_C, X_test_C, y_train_C, y_test_C = train_test_split(df_features, df_target_Customers, 
                                                    test_size=0.2, 
                                                    random_state=150, # 내부적으로 사용되는 난수 값
                                                    shuffle=True) #  데이터를 분리할 때 랜덤으로 분리할지의 유무
                                                     
# stratify (array) : 분리하기 이전의 클래스 비율을 분리하고 나서도 유지하기 위해 설정해야 하는 값 (종속변수의 컬럼을 넣어주면 됩니다.)
# 원본 데이터의 클래스 비율이 8:2라면 분리된 train data, valid(test) data의 클래스 비율도 8:2가 유지됩니다.
# 따라서 stratify 파라미터는 분류 문제에서만 사용 가능합니다.

# %% [markdown]
# # 데이터셋 확인 shape()

# %%
print(X_train_S.shape)
print(X_test_S.shape)
print(y_train_S.shape)
print(y_test_S.shape)
# Out:
# (53520, 17)
# (13381, 17)
# (53520,)
# (13381,)

# %%
print(X_train_C.shape)
print(X_test_C.shape)
print(y_train_C.shape)
print(y_test_C.shape)
# Out:
# (53520, 17)
# (13381, 17)
# (53520,)
# (13381,)

# %% [markdown]
# # DecisionTreeClassifier 모델 학습

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics

regressor_S = DecisionTreeRegressor()               # 종속변수가 현재 범주형
regressor_S.fit(X_train_S, y_train_S) # feature, target
# Out:
# DecisionTreeRegressor()

# %%
regressor_C = DecisionTreeRegressor() #종속변수가 현재 범주형
# random_state=1, min_samples_leaf=35, max_depth=10
regressor_C.fit(X_train_C, y_train_C) # feature, target
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## target(=Sales) MSE 확인하기

# %%
from sklearn.metrics import make_scorer

# kaggle에 따른 오류 계산 함수
def rmspe(y, y_hat):
    return np.sqrt(np.mean(((y - y_hat) / y) ** 2))

rmpse_scorer = make_scorer(rmspe, greater_is_better = False) # Loss function

def score(regressor_S, X_train_S, y_train_S, y_test_S, y_hat):
    score = cross_val_score(regressor_S, X_train_S, y_train_S, scoring=rmpse_scorer, cv=5)
    print('Mean', score.mean())
    print('Variance', score.var())
    print('RMSPE', rmspe(y_test_S, y_hat))

# %%
y_hat = regressor_S.predict(X_test_S)
score(regressor_S, X_train_S, y_train_S, y_test_S, y_hat)
# Out:
# Mean -0.20059878537993253
# Variance 5.7036109772558035e-05
# RMSPE 0.19025687680080464

# %% [markdown]
# ## target(=Customers) MSE 확인하기

# %%
from sklearn.metrics import make_scorer

# kaggle에 따른 오류 계산 함수
def rmspe(y, y_hat):
    return np.sqrt(np.mean(((y - y_hat) / y) ** 2))

rmpse_scorer = make_scorer(rmspe, greater_is_better = False) # Loss function

def score(regressor_C, X_train_C, y_train_C, y_test_C, y_hat):
    score = cross_val_score(regressor_C, X_train_C, y_train_C, scoring=rmpse_scorer, cv=5)
    print('Mean', score.mean())
    print('Variance', score.var())
    print('RMSPE', rmspe(y_test_C, y_hat))

# %%
y_hat = regressor_C.predict(X_test_C)
score(regressor_C, X_train_C, y_train_C, y_test_C, y_hat)
# Out:
# Mean -0.12560754633051668
# Variance 1.4458452624197186e-05
# RMSPE 0.13041607800571187

# %% [markdown]
# # 예측하기

# %%
pred = regressor_S.predict(X_test_S)

# %%
####################### 리스트 - > 데이터프레임 변환 #########################
df_Sales = pd.DataFrame(pred, columns = ['Sales'])
df_Sales
# Out:
#          Sales
# 0      14912.0
# 1       3612.0
# 2       8547.0
# 3      10678.0
# 4       5691.0
# ...        ...
# 13376   6808.0
# 13377   5485.0
# 13378   4907.0
# 13379   9943.0
# 13380      0.0
#
# [13381 rows x 1 columns]

# %%
pred = regressor_C.predict(X_test_C)

# %%
####################### 리스트 - > 데이터프레임 변환 #########################

df_Customers = pd.DataFrame(pred, columns = ['Customers'])
df_Customers
# Out:
#        Customers
# 0          407.0
# 1          521.0
# 2          683.0
# 3          798.0
# 4          795.0
# ...          ...
# 13376      667.0
# 13377      504.0
# 13378      452.0
# 13379      879.0
# 13380        0.0
#
# [13381 rows x 1 columns]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 예측을 위한 데이터 불러오기(test.csv)

# %%
types = {'StateHoliday': np.dtype(str)}

df_test = pd.read_csv(r"./test.csv", parse_dates=[3], dtype=types)

# %%
df_test
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          4 2015-09-17   1.0      1            0
# 1          2      3          4 2015-09-17   1.0      1            0
# 2          3      7          4 2015-09-17   1.0      1            0
# 3          4      8          4 2015-09-17   1.0      1            0
# 4          5      9          4 2015-09-17   1.0      1            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 41083  41084   1111          6 2015-08-01   1.0      0            0
# 41084  41085   1112          6 2015-08-01   1.0      0            0
# 41085  41086   1113          6 2015-08-01   1.0      0            0
# 41086  41087   1114          6 2015-08-01   1.0      0            0
# 41087  41088   1115          6 2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 41083              0
# 41084              0
# 41085              0
# 41086              0
# 41087              1
#
# [41088 rows x 8 columns]

# %% [markdown]
# # Date 쪼개기

# %%
############# Datetime -> String 형변환 -> 구분자로 나누기 작업 #################
df_test['Year'] = df_test['Date'].dt.year
df_test['Month'] = df_test['Date'].dt.month
df_test['Day'] = df_test['Date'].dt.day

# %%
df_test
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          4 2015-09-17   1.0      1            0
# 1          2      3          4 2015-09-17   1.0      1            0
# 2          3      7          4 2015-09-17   1.0      1            0
# 3          4      8          4 2015-09-17   1.0      1            0
# 4          5      9          4 2015-09-17   1.0      1            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 41083  41084   1111          6 2015-08-01   1.0      0            0
# 41084  41085   1112          6 2015-08-01   1.0      0            0
# 41085  41086   1113          6 2015-08-01   1.0      0            0
# 41086  41087   1114          6 2015-08-01   1.0      0            0
# 41087  41088   1115          6 2015-08-01   1.0      0            0
#
#        SchoolHoliday  Year  Month  Day
# 0                  0  2015      9   17
# 1                  0  2015      9   17
# 2                  0  2015      9   17
# 3                  0  2015      9   17
# 4                  0  2015      9   17
# ...              ...   ...    ...  ...
# 41083              0  2015      8    1
# 41084              0  2015      8    1
# 41085              0  2015      8    1
# 41086              0  2015      8    1
# 41087              1  2015      8    1
#
# [41088 rows x 11 columns]

# %% [markdown]
# ### 의미없는 데이터 drop

# %%
df_test.drop(labels='Date',axis=1, inplace=True)

# %%
df_test.drop(labels='Id',axis=1, inplace=True)

# %%
df_test
# Out:
#        Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday  Year  Month  \
# 0          1          4   1.0      1            0              0  2015      9
# 1          3          4   1.0      1            0              0  2015      9
# 2          7          4   1.0      1            0              0  2015      9
# 3          8          4   1.0      1            0              0  2015      9
# 4          9          4   1.0      1            0              0  2015      9
# ...      ...        ...   ...    ...          ...            ...   ...    ...
# 41083   1111          6   1.0      0            0              0  2015      8
# 41084   1112          6   1.0      0            0              0  2015      8
# 41085   1113          6   1.0      0            0              0  2015      8
# 41086   1114          6   1.0      0            0              0  2015      8
# 41087   1115          6   1.0      0            0              1  2015      8
#
#        Day
# 0       17
# 1       17
# 2       17
# 3       17
# 4       17
# ...    ...
# 41083    1
# 41084    1
# 41085    1
# 41086    1
# 41087    1
#
# [41088 rows x 9 columns]

# %% [markdown]
# # 인코딩 작업

# %%
df_test = pd.merge(df_test,store, on='Store', how='left') # default값 how='left'

# %%
############################ 인코딩된 결과 확인 ############################

df_test
# Out:
#        Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday  Year  Month  \
# 0          1          4   1.0      1            0              0  2015      9
# 1          3          4   1.0      1            0              0  2015      9
# 2          7          4   1.0      1            0              0  2015      9
# 3          8          4   1.0      1            0              0  2015      9
# 4          9          4   1.0      1            0              0  2015      9
# ...      ...        ...   ...    ...          ...            ...   ...    ...
# 41083   1111          6   1.0      0            0              0  2015      8
# 41084   1112          6   1.0      0            0              0  2015      8
# 41085   1113          6   1.0      0            0              0  2015      8
# 41086   1114          6   1.0      0            0              0  2015      8
# 41087   1115          6   1.0      0            0              1  2015      8
#
#        Day StoreType Assortment  CompetitionDistance  \
# 0       17         c          a               1270.0
# 1       17         a          a              14130.0
# 2       17         a          c              24000.0
# 3       17         a          a               7520.0
# 4       17         a          c               2030.0
# ...    ...       ...        ...                  ...
# 41083    1         a          a               1900.0
# 41084    1         c          c               1880.0
# 41085    1         a          c               9260.0
# 41086    1         a          c                870.0
# 41087    1         d          c               5350.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           12.0                    2006.0       1
# 2                            4.0                    2013.0       0
# 3                           10.0                    2014.0       0
# 4                            8.0                    2000.0       0
# ...                          ...                       ...     ...
# 41083                        6.0                    2014.0       1
# 41084                        4.0                    2006.0       0
# 41085                        NaN                       NaN       0
# 41086                        NaN                       NaN       0
# 41087                        NaN                       NaN       1
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                  NaN              NaN               NaN
# 1                 14.0           2011.0   Jan,Apr,Jul,Oct
# 2                  NaN              NaN               NaN
# 3                  NaN              NaN               NaN
# 4                  NaN              NaN               NaN
# ...                ...              ...               ...
# 41083             31.0           2013.0   Jan,Apr,Jul,Oct
# 41084              NaN              NaN               NaN
# 41085              NaN              NaN               NaN
# 41086              NaN              NaN               NaN
# 41087             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [41088 rows x 18 columns]

# %%
############################ NaN값 0으로 초기화 ############################

df_test = df_test.fillna(0)

# %%
df_test['StateHoliday'].unique()
# Out:
# array(['0', 'a'], dtype=object)

# %%
df_test['StoreType'].unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
df_test['Assortment'].unique()
# Out:
# array(['a', 'c', 'b'], dtype=object)

# %%
############################ 인코딩 함수 만들기 ############################

def label_encode(df, col):
    df_labelled_encode = df.copy()
    # 다른 클래스에 대해 다른 숫자를 지정하는 딕셔너리
    label_encode = {col: {'a':0, 'b':1, 'c':2}}
    # .replace를 사용하여 서로 다른 클래스를 숫자로 변경
    df_labelled_encode.replace(label_encode,inplace=True)
    return df_labelled_encode

# %%
############################ 인코딩 작업 ############################

df_test = label_encode(df_test, "StateHoliday")

# %%
############################ 인코딩 작업 ############################

df_test = label_encode(df_test, "StoreType")

# %%
############################ 인코딩 작업 ############################

df_test = label_encode(df_test, "Assortment")

# %% [markdown]
# ## 제대로 인코딩 됐는지 확인하는 작업

# %%
df_test['Assortment'].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %% [markdown]
# ## 의미없는 데이터 PromoInterval 제거

# %%
df_test.drop(labels='PromoInterval',axis=1, inplace=True)

# %%
df_test
# Out:
#        Store  DayOfWeek  Open  Promo  StateHoliday  SchoolHoliday  Year  \
# 0          1          4   1.0      1             0              0  2015
# 1          3          4   1.0      1             0              0  2015
# 2          7          4   1.0      1             0              0  2015
# 3          8          4   1.0      1             0              0  2015
# 4          9          4   1.0      1             0              0  2015
# ...      ...        ...   ...    ...           ...            ...   ...
# 41083   1111          6   1.0      0             0              0  2015
# 41084   1112          6   1.0      0             0              0  2015
# 41085   1113          6   1.0      0             0              0  2015
# 41086   1114          6   1.0      0             0              0  2015
# 41087   1115          6   1.0      0             0              1  2015
#
#        Month  Day  StoreType  Assortment  CompetitionDistance  \
# 0          9   17          2           0               1270.0
# 1          9   17          0           0              14130.0
# 2          9   17          0           2              24000.0
# 3          9   17          0           0               7520.0
# 4          9   17          0           2               2030.0
# ...      ...  ...        ...         ...                  ...
# 41083      8    1          0           0               1900.0
# 41084      8    1          2           2               1880.0
# 41085      8    1          0           2               9260.0
# 41086      8    1          0           2                870.0
# 41087      8    1          3           2               5350.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           12.0                    2006.0       1
# 2                            4.0                    2013.0       0
# 3                           10.0                    2014.0       0
# 4                            8.0                    2000.0       0
# ...                          ...                       ...     ...
# 41083                        6.0                    2014.0       1
# 41084                        4.0                    2006.0       0
# 41085                        0.0                       0.0       0
# 41086                        0.0                       0.0       0
# 41087                        0.0                       0.0       1
#
#        Promo2SinceWeek  Promo2SinceYear
# 0                  0.0              0.0
# 1                 14.0           2011.0
# 2                  0.0              0.0
# 3                  0.0              0.0
# 4                  0.0              0.0
# ...                ...              ...
# 41083             31.0           2013.0
# 41084              0.0              0.0
# 41085              0.0              0.0
# 41086              0.0              0.0
# 41087             22.0           2012.0
#
# [41088 rows x 17 columns]

# %% [markdown]
# # 예측하기

# %%
####################### 리스트 - > 데이터프레임 변환 #########################
pred = regressor_S.predict(df_test)
df_Sales = pd.DataFrame(pred, columns = ['Sales'])
df_Sales
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
#          Sales
# 0       5881.0
# 1       6457.0
# 2       7961.0
# 3      10288.0
# 4       5881.0
# ...        ...
# 41083   5650.0
# 41084   7597.0
# 41085  22017.0
# 41086  22017.0
# 41087  21312.0
#
# [41088 rows x 1 columns]

# %%
####################### 리스트 - > 데이터프레임 변환 #########################
pred = regressor_C.predict(df_test)
df_Customers = pd.DataFrame(pred, columns = ['Customers'])
df_Customers
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
#        Customers
# 0          357.0
# 1          466.0
# 2          357.0
# 3          357.0
# 4          357.0
# ...          ...
# 41083      312.0
# 41084      287.0
# 41085     3784.0
# 41086     3784.0
# 41087     3745.0
#
# [41088 rows x 1 columns]

# %% [markdown]
# # 예측한 결과 합치기(merge)

# %%
##################### merge하기 위해서 index값 매기기 #####################
df_Sales = df_Sales.reset_index()
df_Sales
# Out:
#        index    Sales
# 0          0   5881.0
# 1          1   6457.0
# 2          2   7961.0
# 3          3  10288.0
# 4          4   5881.0
# ...      ...      ...
# 41083  41083   5650.0
# 41084  41084   7597.0
# 41085  41085  22017.0
# 41086  41086  22017.0
# 41087  41087  21312.0
#
# [41088 rows x 2 columns]

# %%
##################### merge하기 위해서 index값 매기기 #####################

df_Customers = df_Customers.reset_index()
df_Customers
# Out:
#        index  Customers
# 0          0      357.0
# 1          1      466.0
# 2          2      357.0
# 3          3      357.0
# 4          4      357.0
# ...      ...        ...
# 41083  41083      312.0
# 41084  41084      287.0
# 41085  41085     3784.0
# 41086  41086     3784.0
# 41087  41087     3745.0
#
# [41088 rows x 2 columns]

# %%
df_submit = pd.merge(df_Sales,df_Customers, on='index', how='left') # default값 how='left'

# %%
df_submit
# Out:
#        index    Sales  Customers
# 0          0   5881.0      357.0
# 1          1   6457.0      466.0
# 2          2   7961.0      357.0
# 3          3  10288.0      357.0
# 4          4   5881.0      357.0
# ...      ...      ...        ...
# 41083  41083   5650.0      312.0
# 41084  41084   7597.0      287.0
# 41085  41085  22017.0     3784.0
# 41086  41086  22017.0     3784.0
# 41087  41087  21312.0     3745.0
#
# [41088 rows x 3 columns]

# %%
df_submit.rename(columns = {'index':'Id'}, inplace=True)

# %%
df_submit
# Out:
#           Id    Sales  Customers
# 0          0   5881.0      357.0
# 1          1   6457.0      466.0
# 2          2   7961.0      357.0
# 3          3  10288.0      357.0
# 4          4   5881.0      357.0
# ...      ...      ...        ...
# 41083  41083   5650.0      312.0
# 41084  41084   7597.0      287.0
# 41085  41085  22017.0     3784.0
# 41086  41086  22017.0     3784.0
# 41087  41087  21312.0     3745.0
#
# [41088 rows x 3 columns]

# %% [markdown]
# # 최종결과

# %%
sample_submission = pd.read_csv(r"./sample_submission.csv")
sample_submission
# Out:
#           Id  Sales
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 41083  41084      0
# 41084  41085      0
# 41085  41086      0
# 41086  41087      0
# 41087  41088      0
#
# [41088 rows x 2 columns]

# %%
sample_submission.drop(labels='Sales',axis=1, inplace=True)

# %%
submit = pd.merge(sample_submission,df_submit, on='Id', how='left') # default값 how='left'

# %%
submit.isnull().sum()
# Out:
# Id           0
# Sales        1
# Customers    1
# dtype: int64

# %%
submit = submit.dropna(axis=0)

# %%
submit
# Out:
#           Id    Sales  Customers
# 0          1   6457.0      466.0
# 1          2   7961.0      357.0
# 2          3  10288.0      357.0
# 3          4   5881.0      357.0
# 4          5   5881.0      357.0
# ...      ...      ...        ...
# 41082  41083   5650.0      312.0
# 41083  41084   7597.0      287.0
# 41084  41085  22017.0     3784.0
# 41085  41086  22017.0     3784.0
# 41086  41087  21312.0     3745.0
#
# [41087 rows x 3 columns]

# %% [markdown]
# # 제출

# %%
import os

submit.to_csv("submission.csv", index = True)
